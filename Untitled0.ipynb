# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyoti-Bansal98/Python-practice/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
print(10+40)
# Out:
# 50

# %%
import torch
